# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
import os

# %%
sys.path
# Out:
# ['',
#  '/Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python36.zip',
#  '/Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6',
#  '/Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6/lib-dynload',
#  '/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6',
#  '/Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6/site-packages',
#  '/Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6/site-packages/IPython/extensions',
#  '/Users/lisa1010/.ipython']

# %%
paths_to_add = ['/Users/lisa1010/dev/Melydi/melydi']

# %%
for p in paths_to_add:
    if p not in sys.path:
        sys.path.append(p)

# %%
from signal_processing.pitch_processing import *

# %%
data_folder = '/Users/lisa1010/dev/Melydi/melydi/data_old/piano_notes/one_octave/'

# %%
fname = 'A2.wav'
fpath = os.path.join(data_folder, fname)
fs, x = read(fpath)
x = np.array(x, np.float)
x /= max(abs(x))
ton = get_onset(fs, x)
f0 = get_f0(fs, x[int(ton*fs):int(ton*fs)+2048])
# f0 = get_f0(fs, x)
print (f0)
# Out:
# Delta x: mean: 136.80154868314466, std: 73.10251546195684
# Slopes: mean: 0.35597321809856486, std: 0.31114881297603086
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-784f3932a4e2> in <module>()
#       5 x /= max(abs(x))
#       6 ton = get_onset(fs, x)
# ----> 7 f0 = get_f0(fs, x[int(ton*fs):int(ton*fs)+2048])
#       8 # f0 = get_f0(fs, x)
#       9 print (f0)
#
# /Users/lisa1010/dev/Melydi/melydi/signal_processing/pitch_processing.py in get_f0(fs, x)
#     165 def get_f0(fs, x):
#     166     list_of_peaks, f_peaks, dBs = get_peaks(fs, x)
# --> 167     f0 = kmeans_f0(list_of_peaks)
#     168     return f0
#     169
#
# /Users/lisa1010/dev/Melydi/melydi/signal_processing/pitch_processing.py in kmeans_f0(list_of_peaks)
#     155
#     156 def kmeans_f0(list_of_peaks):
# --> 157     f_peaks = zip(*list_of_peaks)[0]
#     158     km = KMeans()
# ...

# %%
list_of_peaks, f_peaks, dBs = get_peaks(fs, x[int(ton*fs):int(ton*fs)+2048])
# Out:
# [autoreload of signal_processing.pitch_processing failed: Traceback (most recent call last):
#   File "/Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ModuleNotFoundError: No module named 'sklearn'
# ]
# Delta x: mean: 136.80154868314466, std: 73.10251546195684
# Slopes: mean: 0.35597321809856486, std: 0.31114881297603086

# %%
peak_quality(peaks_gold)
# Out:
# Delta x: mean: 205.20232302471697, std: 44.1764524110965
# Slopes: mean: 0.06790468550370449, std: 0.10136808171110136

# %%
f_peaks
# Out:
# array([ 128.70509761,  217.15977464,  283.20428767,  320.71681137,
#         440.42004458,  661.21268829,  878.76713198,  931.08488539,
#        1099.3219752 , 1145.85670093, 1322.30483011, 1545.45551259,
#        1770.32368181])

# %%
data = [6,6,0,6,5,4,7,6,30]

# %%
detect_outliers(data)
# Out:
# [0, 4, 5, 6, 6, 6, 6, 7, 30]
# 2
# 10.0
# 2.0
# [2, 8]

# %%
indices_remove = [0,2,3,7,9]

# %%
peaks_gold = []
for i in range(len(f_peaks)):
    if i not in indices_remove:
        peaks_gold.append(list_of_peaks[i])

# %%
peaks_gold
# Out:
# [(217.15977463592753, -0.6845668105806908),
#  (440.4200445805057, 0.03495392519107554),
#  (661.212688290036, -32.72726043637158),
#  (878.7671319762429, -36.56784536103805),
#  (1099.321975201258, -40.202768639115675),
#  (1322.3048301081383, -45.16786593368306),
#  (1545.4555125876266, -42.5746596888348),
#  (1770.3236818066978, -45.80030427048041)]

# %%
peak_quality(peaks_gold)
# Out:
# Delta x: mean: 221.8805581672529, std: 2.246077302278398
# Slopes: mean: 0.033424826211394934, std: 0.04724964836835156

# %%
os.listdir(data_folder)
# Out:
# ['F4.wav',
#  'Gb4.wav',
#  'Eb4.wav',
#  'Ab4.wav',
#  'G4.wav',
#  'A2.wav',
#  'Db4.wav',
#  'Bb3.wav',
#  'Pipfile',
#  'C4.wav',
#  'B3.wav',
#  'D4.wav',
#  'E4.wav']

# %%
for fname in os.listdir(data_folder):
    fpath = os.path.join(data_folder, fname)
    print (fname)
    fs, x = read(fpath)
    x = np.array(x, np.float)
    x /= max(abs(x))
    ton = get_onset(fs, x)
    f0 = get_f0(fs, x[int(ton*fs):int(ton*fs)+2048])


    print (f0)
# Out:
# F4.wav
# 165.67848550451333
# Gb4.wav
# 142.5037218957592
# Eb4.wav
# 179.85395362045415
# Ab4.wav
# 109.34822892103415
# G4.wav
# 394.8708001414591
# A2.wav
# 143.9701615131684
# Db4.wav
# 73.0935994433568
# Bb3.wav
# 87.04021997114893
# Pipfile
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-563211ab2a2f> in <module>()
#       2     fpath = os.path.join(data_folder, fname)
#       3     print (fname)
# ----> 4     fs, x = read(fpath)
#       5     x = np.array(x, np.float)
#       6     x /= max(abs(x))
#
# /Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     234
#     235     try:
# --> 236         file_size, is_big_endian = _read_riff_chunk(fid)
#     237         fmt_chunk_received = False
#     238         channels = 1
#
# ...

# %%
for fname in os.listdir(data_folder):
    fpath = os.path.join(data_folder, fname)
    print (fname)
    fs, x = read(fpath)
    x = np.array(x, np.float)
    x /= max(abs(x))
    ton = get_onset(fs, x)
    f0 = get_f0(fs, x[int(ton*fs):int(ton*fs)+2048])
    print (f0)
# Out:
# F4.wav
# 165.67848550451333
# Gb4.wav
# 142.5037218957592
# Eb4.wav
# 179.85395362045415
# Ab4.wav
# 109.34822892103415
# G4.wav
# 394.8708001414591
# A2.wav
# 143.9701615131684
# Db4.wav
# 73.0935994433568
# Bb3.wav
# 87.04021997114893
# Pipfile
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-854511ecb147> in <module>()
#       2     fpath = os.path.join(data_folder, fname)
#       3     print (fname)
# ----> 4     fs, x = read(fpath)
#       5     x = np.array(x, np.float)
#       6     x /= max(abs(x))
#
# /Users/lisa1010/.virtualenvs/melydi-nziHeQot/lib/python3.6/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     234
#     235     try:
# --> 236         file_size, is_big_endian = _read_riff_chunk(fid)
#     237         fmt_chunk_received = False
#     238         channels = 1
#
# ...
